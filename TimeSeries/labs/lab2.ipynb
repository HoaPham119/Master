# %%
library(astsa)

# %%
chicken
# Out:
#      Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct
# 2001                                                   65.58  66.48  65.70
# 2002  62.94  62.92  62.73  62.50  63.35  63.80  64.21  64.11  64.04  63.00
# 2003  62.27  63.13  63.86  63.53  64.60  65.99  67.50  68.50  69.23  68.57
# 2004  69.58  71.59  73.09  74.75  76.59  79.63  80.94  80.10  78.16  76.00
# 2005  73.44  73.75  73.88  74.00  74.29  74.48  74.75  74.77  75.19  74.38
# 2006  69.86  69.18  68.29  67.52  67.87  68.98  69.90  70.42  70.69  69.65
# 2007  71.33  73.77  76.37  78.10  79.52  80.75  81.17  81.27  81.55  79.75
# 2008  77.25  79.15  81.23  82.04  83.46  85.71  88.25  88.42  88.40  87.54
# 2009  87.25  86.70  85.73  85.38  86.96  88.17  88.56  86.77  84.88  82.85
# 2010  83.04  83.30  84.00  85.28  86.45  87.17  87.84  87.79  87.75  86.73
# 2011  85.00  85.07  86.08  86.40  86.54  86.94  87.34  88.13  88.98  89.00
# 2012  90.35  91.17  92.79  93.25  94.06  94.50  94.73  95.02  95.65  95.84
# ...

# %% [markdown]
# # VẼ TIMESERIES DATA

# %%
plot(chicken, 
     main = "Time Series Data", 
     ylab = "Price", 
     xlab = "Time", 
     col = "blue", 
     lwd = 2)
# Out:
# Plot with title “Time Series Data”

# %%
plot(chicken, 
     main = "Time Series Data", 
     ylab = "Price", 
     xlab = "Time", 
     col = "blue", 
     lwd = 2)
# Out:
# Plot with title “Time Series Data”

# %% [markdown]
# # ÁP DỤNG DETRENDING

# %%
lm_model = lm(chicken ~ time(chicken))
lm_model
# Out:
# Call:
# lm(formula = chicken ~ time(chicken))
#
# Coefficients:
#   (Intercept)  time(chicken)
#     -7131.022          3.592

# %%
b0 = lm_model$coefficients[1]
b1 = lm_model$coefficients[2]

# %%
y_trend = chicken - b0 - b1*(time((chicken)))
y_trend
# Out:
#      Jan         Feb         Mar         Apr         May         Jun
# 2001
# 2002  2.56071036  2.24136796  1.75202556  1.22268317  1.77334077  1.92399837
# 2003 -1.70139841 -1.14074081 -0.71008321 -1.33942560 -0.56876800  0.52188960
# 2004  2.01649282  3.72715042  4.92780803  6.28846563  7.82912323 10.56978083
# 2005  2.28438405  2.29504165  2.12569926  1.94635686  1.93701446  1.82767206
# 2006 -4.88772472 -5.86706711 -7.05640951 -8.12575191 -8.07509431 -7.26443670
# 2007 -7.00983349 -4.86917588 -2.56851828 -1.13786068 -0.01720308  0.91345453
# 2008 -4.68194225 -3.08128465 -1.30062705 -0.78996945  0.33068816  2.28134576
# 2009  1.72594898  0.87660658 -0.39273582 -1.04207822  0.23857939  1.14923699
# 2010 -6.07615979 -6.11550219 -5.71484459 -4.73418698 -3.86352938 -3.44287178
# 2011 -7.70826856 -7.93761096 -7.22695336 -7.20629575 -7.36563815 -7.26498055
# 2012 -5.95037733 -5.42971973 -4.10906212 -3.94840452 -3.43774692 -3.29708932
# ...

# %% [markdown]
# # ÁP DỤNG PHƯƠNG PHÁP DIFFERENCING

# %%
diff_checken = diff(chicken, lag= 1)
diff_checken
# Out:
#      Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# 2001                                                  0.90 -0.78 -1.37 -1.10
# 2002 -0.29 -0.02 -0.19 -0.23  0.85  0.45  0.41 -0.10 -0.07 -1.04 -1.10 -0.41
# 2003  0.78  0.86  0.73 -0.33  1.07  1.39  1.51  1.00  0.73 -0.66 -0.21  0.62
# 2004  0.60  2.01  1.50  1.66  1.84  3.04  1.31 -0.84 -1.94 -2.16 -1.29 -1.11
# 2005 -0.16  0.31  0.13  0.12  0.29  0.19  0.27  0.02  0.42 -0.81 -1.69 -1.48
# 2006 -1.35 -0.68 -0.89 -0.77  0.35  1.11  0.92  0.52  0.27 -1.04 -0.65  0.35
# 2007  1.98  2.44  2.60  1.73  1.42  1.23  0.42  0.10  0.28 -1.80 -1.98 -0.92
# 2008  0.40  1.90  2.08  0.81  1.42  2.25  2.54  0.17 -0.02 -0.86 -0.61  0.09
# 2009  0.23 -0.55 -0.97 -0.35  1.58  1.21  0.39 -1.79 -1.89 -2.03 -0.72  0.02
# 2010  0.89  0.26  0.70  1.28  1.17  0.72  0.67 -0.05 -0.04 -1.02 -1.27 -0.11
# 2011 -0.35  0.07  1.01  0.32  0.14  0.40  0.40  0.79  0.85  0.02  0.23  0.59
# ...

# %%
# Set up the plotting area to have 1 row and 2 columns
par(mfrow=c(3,1))

plot(chicken, type = "l", col = "#8aba8f", lwd = 2, ylab = "Values", xlab = "Time", main = "Chicken")

plot(y_trend, type = "l", col = "#871c82", lwd = 2, ylab = "Values", xlab = "Time", main = "Detrending")

plot(diff_checken, type = "l", col = "#b93434", lwd = 2, ylab = "Values", xlab = "Time", main = "Defferencing")
# Out:
# Plot with title “Defferencing”

# %%
?diff
# Out:
# diff                   package:base                    R Documentation
#
# s
#
# n:
#
#      Returns suitably lagged and iterated differences.
#
# e:
#
#      diff(x, ...)
#
#      ## Default S3 method:
#      diff(x, lag = 1, differences = 1, ...)
#
#      ## S3 method for class 'POSIXt'
#      diff(x, lag = 1, differences = 1, ...)
#
#      ## S3 method for class 'Date'
#      diff(x, lag = 1, differences = 1, ...)
#
# s:
#
#        x: a numeric vector or matrix containing the values to be
#           differenced.
#
#      lag: an integer indicating which lag to use.
#
# differences: an integer indicating the order of the difference.
#
#      ...: further arguments to be passed to or from methods.
#
# s:
#
#      ‘diff’ is a generic function with a default method and ones for
#      classes ‘"ts"’, ‘"POSIXt"’ and ‘"Date"’.
#
#      ‘NA’'s propagate.
#
# e:
#
#      If ‘x’ is a vector of length ‘n’ and ‘differences = 1’, then the
# ...

# %%
diff_checken = diff(chicken,lag = 3)
diff_checken
# Out:
#      Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# 2001                                                             -1.25 -3.25
# 2002 -2.76 -1.41 -0.50 -0.44  0.43  1.07  1.71  0.76  0.24 -1.21 -2.21 -2.55
# 2003 -0.73  1.23  2.37  1.26  1.47  2.13  3.97  3.90  3.24  1.07 -0.14 -0.25
# 2004  1.01  3.23  4.11  5.17  5.00  6.54  6.19  3.51 -1.47 -4.94 -5.39 -4.56
# 2005 -2.56 -0.96  0.28  0.56  0.54  0.60  0.75  0.48  0.71 -0.37 -2.08 -3.98
# 2006 -4.52 -3.51 -2.92 -2.34 -1.31  0.69  2.38  2.55  1.71 -0.25 -1.42 -1.34
# 2007  1.68  4.77  7.02  6.77  5.75  4.38  3.07  1.75  0.80 -1.42 -3.50 -4.70
# 2008 -2.50  1.38  4.38  4.79  4.31  4.48  6.21  4.96  2.69 -0.71 -1.49 -1.38
# 2009 -0.29 -0.23 -1.29 -1.87  0.26  2.44  3.18 -0.19 -3.29 -5.71 -4.64 -2.73
# 2010  0.19  1.17  1.85  2.24  3.15  3.17  2.56  1.34  0.58 -1.11 -2.33 -2.40
# 2011 -1.73 -0.39  0.73  1.40  1.47  0.86  0.94  1.59  2.04  1.66  1.10  0.84
# ...

# %%
# Set up the plotting area to have 1 row and 2 columns
par(mfrow=c(3,1))

plot(chicken, type = "l", col = "#8aba8f", lwd = 2, ylab = "Values", xlab = "Time", main = "Chicken")

plot(y_trend, type = "l", col = "#871c82", lwd = 2, ylab = "Values", xlab = "Time", main = "Detrending")

plot(diff_checken, type = "l", col = "#871c82", lwd = 2, ylab = "Values", xlab = "Time", main = "Defferencing")
# Out:
# Plot with title “Defferencing”
